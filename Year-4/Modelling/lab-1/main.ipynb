# %%
import csv

data = []
var_num = str(51)
fname = 'УИР1_ВАРИАНТЫ-23-51-104.csv'

with open(fname) as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        data.append(float(row[var_num]))

# %%
# математическое ожидание
def expected_value(data):
    s = 0
    for e in data:
        s += e
    return s / len(data)
    
# дисперсия
def variance(data):
    s = 0
    m = expected_value(data)
    n = len(data)
    for e in data:
        s += (e ** 2)
    return s / n - m ** 2
    
# same as above but computed different
def variance2(data):
    s = 0
    m = expected_value(data)
    n = len(data)
    for e in data:
        s += (e - m) ** 2
    return s / n

# несмещенная дисперсия
def unbiased_variance(data):
    var = variance(data)
    n = len(data)
    return var * (n / (n - 1))
    
# среднеквадратическое отклонение
def sko_of_x(data):
    return unbiased_variance(data) ** 0.5
    
def sko_of_m(data):
    return (unbiased_variance(data) / len(data)) ** 0.5
    
def deviation_e(data, p):
    ts = {
        0.9 : 1.643,
        0.95: 1.960,
        0.99: 2.576
    }

    if p not in ts.keys():
        raise "unknown value"

    return sko_of_m(data) * ts[p]

# доверительный интервал
def confidence_interval(data, p):
    m = expected_value(data)
    e = deviation_e(data, p)
    return (m, e)

# вариация
def variation(data):
    m = expected_value(data)
    sko = sko_of_x(data)
    return sko / m
    
def relative_deviation_percent(val, exp):
    return 100 * (val - exp) / exp

# %%
def analyze(data, bounds, idx300, conf_int_vals):
    expected_values = []
    unbiased_variances = []
    confidence_intervals = []
    sko_of_xs = []
    variations = []

    for bound in bounds:
        cur_data = data[0:bound]
        expected_values.append(expected_value(cur_data))
        unbiased_variances.append(variance(cur_data))
        sko_of_xs.append(sko_of_x(cur_data))
        variations.append(variation(cur_data))

        bound_conf_ints = []
        for p in conf_int_vals:
            bound_conf_ints.append(confidence_interval(cur_data, p))
        confidence_intervals.append(bound_conf_ints)
        
        
    for i in range(len(bounds)):
        bi = bounds[i]
        exp_vali = expected_values[i]
        exp_val300 = expected_values[idx300]
        rel_exp_val = relative_deviation_percent(exp_vali, exp_val300)
        print(f"for bounds {bounds[i]}:")
        print(f"\texp_val={round(exp_vali, 3)}, rel={round(rel_exp_val, 3)}%")

        for j in range(len(conf_int_vals)):
            conf_int_m = confidence_intervals[i][j][0]
            conf_int_e = confidence_intervals[i][j][1]
            rel_conf_int_m = relative_deviation_percent(conf_int_m, confidence_intervals[idx300][j][0])
            rel_conf_int_e = relative_deviation_percent(conf_int_e, confidence_intervals[idx300][j][1])
            print(f"\tconf_int {conf_int_vals[j]}: {round(conf_int_m, 3)} +- {round(conf_int_e, 3)}")
            print(f"\tconf_int {conf_int_vals[j]} rel: {round(rel_conf_int_m, 3)}% +- {round(rel_conf_int_e, 3)}%")

        vari = unbiased_variances[i]
        rel_vari = relative_deviation_percent(vari, unbiased_variances[idx300])
        print(f"\tvariance: {round(vari, 3)}, rel={round(rel_vari, 3)}%")
        
        skoi = sko_of_xs[i]
        rel_skoi = relative_deviation_percent(skoi, sko_of_xs[idx300])
        print(f"\tsko: {round(skoi, 3)}, rel={round(rel_skoi, 3)}%")
        
        variation_i = variations[i]
        rel_variation_i = relative_deviation_percent(variation_i, variations[idx300])
        print(f"\tvariation: {round(variation_i, 3)}, rel={round(rel_variation_i, 3)}%")
        
    return (expected_values, unbiased_variances, confidence_intervals, sko_of_xs, variations)
        

bounds = [10, 20, 50, 100, 200, 300]
idx300 = bounds.index(300)
conf_int_vals = [0.9, 0.95, 0.99]

(expected_values, unbiased_variances, confidence_intervals, sko_of_xs, variations) = analyze(data, bounds, idx300, conf_int_vals)
# Out:
# for bounds 10:
# 	exp_val=21.232, rel=-6.496%
# 	conf_int 0.9: 21.232 +- 20.217
# 	conf_int 0.9 rel: -6.496% +- 446.917%
# 	conf_int 0.95: 21.232 +- 24.117
# 	conf_int 0.95 rel: -6.496% +- 446.917%
# 	conf_int 0.99: 21.232 +- 31.697
# 	conf_int 0.99 rel: -6.496% +- 446.917%
# 	variance: 1362.667, rel=-9.964%
# 	sko: 38.911, rel=-0.147%
# 	variation: 1.833, rel=6.79%
# for bounds 20:
# 	exp_val=24.745, rel=8.971%
# 	conf_int 0.9: 24.745 +- 13.293
# 	conf_int 0.9 rel: 8.971% +- 259.613%
# 	conf_int 0.95: 24.745 +- 15.858
# 	conf_int 0.95 rel: 8.971% +- 259.613%
# 	conf_int 0.99: 24.745 +- 20.842
# 	conf_int 0.99 rel: 8.971% +- 259.613%
# 	variance: 1243.737, rel=-17.823%
# 	sko: 36.183, rel=-7.148%
# 	variation: 1.462, rel=-14.793%
# for bounds 50:
# 	exp_val=25.591, rel=12.7%
# 	conf_int 0.9: 25.591 +- 9.36
# 	conf_int 0.9 rel: 12.7% +- 153.204%
# 	conf_int 0.95: 25.591 +- 11.166
# 	conf_int 0.95 rel: 12.7% +- 153.204%
# 	conf_int 0.99: 25.591 +- 14.675
# 	conf_int 0.99 rel: 12.7% +- 153.204%
# 	variance: 1590.16, rel=5.067%
# 	sko: 40.282, rel=3.37%
# 	variation: 1.574, rel=-8.279%
# for bounds 100:
# 	exp_val=23.521, rel=3.581%
# 	conf_int 0.9: 23.521 +- 6.535
# 	conf_int 0.9 rel: 3.581% +- 76.796%
# 	conf_int 0.95: 23.521 +- 7.796
# 	conf_int 0.95 rel: 3.581% +- 76.796%
# 	conf_int 0.99: 23.521 +- 10.246
# 	conf_int 0.99 rel: 3.581% +- 76.796%
# 	variance: 1566.33, rel=3.492%
# 	sko: 39.776, rel=2.073%
# 	variation: 1.691, rel=-1.456%
# for bounds 200:
# 	exp_val=22.312, rel=-1.743%
# 	conf_int 0.9: 22.312 +- 4.414
# 	conf_int 0.9 rel: -1.743% +- 19.397%
# 	conf_int 0.95: 22.312 +- 5.265
# 	conf_int 0.95 rel: -1.743% +- 19.397%
# 	conf_int 0.99: 22.312 +- 6.92
# 	conf_int 0.99 rel: -1.743% +- 19.397%
# 	variance: 1435.968, rel=-5.121%
# 	sko: 37.989, rel=-2.513%
# 	variation: 1.703, rel=-0.783%
# for bounds 300:
# 	exp_val=22.707, rel=0.0%
# 	conf_int 0.9: 22.707 +- 3.696
# 	conf_int 0.9 rel: 0.0% +- 0.0%
# 	conf_int 0.95: 22.707 +- 4.41
# 	conf_int 0.95 rel: 0.0% +- 0.0%
# 	conf_int 0.99: 22.707 +- 5.796
# 	conf_int 0.99 rel: 0.0% +- 0.0%
# 	variance: 1513.476, rel=0.0%
# 	sko: 38.968, rel=0.0%
# 	variation: 1.716, rel=0.0%

# %%
import matplotlib.pyplot as plt

def plt_show_values(data):
    fig, ax = plt.subplots()

    data_x = range(1, len(data) + 1)
    ax.plot(data_x, data)
    plt.show()
    
plt_show_values(data)

# %%
# ковариация
def covariance(data_a, data_b):
    if len(data_a) != len(data_b):
        raise "len is not same"
    n = len(data_a)
    s = 0
    a_m = expected_value(data_a)
    b_m = expected_value(data_b)
    for i in range(n):
        s += (data_a[i] - a_m) * (data_b[i] - b_m)
    return s / n

# коэффициент автокорелляции
def correlation(data_a, data_b):
    cov = covariance(data_a, data_b)
    sko_a = sko_of_x(data_a)
    sko_b = sko_of_x(data_b)
    return cov / (sko_a * sko_b)

# %%
movs = range(1, 11)
correlation_coefs = []

for mov in movs:
    data_m = data[mov:] + data[0:mov]
    correlation_coefs.append((mov, correlation(data, data_m)))

for mov, corr in correlation_coefs:
    print(f"{mov},\t{round(corr, 3)}")
    
def plt_show_correlations(data):
    fig, ax = plt.subplots()
    ax.plot(data)
    ax.set_ylim([-1, 1])
    plt.show()
    
plt_show_correlations([corr for (_, corr) in correlation_coefs])
# Out:
# 1,	-0.012
# 2,	-0.011
# 3,	-0.108
# 4,	-0.065
# 5,	-0.049
# 6,	-0.014
# 7,	0.073
# 8,	-0.082
# 9,	0.068
# 10,	0.017

# %%
n_bins = 10

def plt_show_hist(data, n_bins=10):
    fig, ax = plt.subplots()
    ax.hist(data, n_bins)
    plt.show()

plt_show_hist(data, n_bins)

# %%
import math

v = variations[idx300]
q_max = 2 / (1 + v**2)
print(f"v={round(v, 3)} => q_max={round(q_max, 3)}")

q = 0.38
if q > q_max:
    print("q > q_max")
else:
    print(f"q={q}")
    
t = expected_values[idx300]
print(f"t={round(t, 3)}")

t1 = (1 + math.sqrt((1 - q)/(2 * q) * (v**2 - 1))) * t
t2 = (1 - math.sqrt((q) / (2 * (1 - q)) * (v ** 2 - 1))) * t
print(f"t1={round(t1, 3)}, t2={round(t2, 3)}")
# Out:
# v=1.716 => q_max=0.507
# q=0.38
# t=22.707
# t1=51.311, t2=5.176

# %%
import random as rd

class Generator:
    def __init__(self, q, t1, t2):
        self.q = q
        self.t1 = t1
        self.t2 = t2
        
    def __exponent(self, m, x):
        return (-1) * math.log(x) * m

    def random(self):
        rq = rd.random()
        rx = rd.random()
        if rq <= q:
            return self.__exponent(self.t1, rx)
        else:
            return self.__exponent(self.t2, rx)

# %%
gen = Generator(q, t1, t2)

rd.seed(22)

n = len(data)
data_gen = []

for i in range(n):
    data_gen.append(gen.random())

# %%
plt_show_values(data)
plt_show_values(data_gen)

# %%
plt_show_hist(data)
plt_show_hist(data_gen)

# %%
def analyze_gen(data_gen, data_analysis, bounds, conf_int_vals):
    (data_ev, data_uv, data_ci, data_sko, data_var) = data_analysis

    expected_values = []
    unbiased_variances = []
    confidence_intervals = []
    sko_of_xs = []
    variations = []

    for bound in bounds:
        cur_data = data_gen[0:bound]
        expected_values.append(expected_value(cur_data))
        unbiased_variances.append(variance(cur_data))
        sko_of_xs.append(sko_of_x(cur_data))
        variations.append(variation(cur_data))

        bound_conf_ints = []
        for p in conf_int_vals:
            bound_conf_ints.append(confidence_interval(cur_data, p))
        confidence_intervals.append(bound_conf_ints)
        
        
    for i in range(len(bounds)):
        bi = bounds[i]
        exp_vali = expected_values[i]
        rel_exp_val = relative_deviation_percent(exp_vali, data_ev[i])
        print(f"for bounds {bounds[i]}:")
        print(f"\texp_val={round(exp_vali, 3)}, rel={round(rel_exp_val, 3)}%")

        for j in range(len(conf_int_vals)):
            conf_int_m = confidence_intervals[i][j][0]
            conf_int_e = confidence_intervals[i][j][1]
            rel_conf_int_m = relative_deviation_percent(conf_int_m, data_ci[i][j][0])
            rel_conf_int_e = relative_deviation_percent(conf_int_e, data_ci[i][j][1])
            print(f"\tconf_int {conf_int_vals[j]}: {round(conf_int_m, 3)} +- {round(conf_int_e, 3)}")
            print(f"\tconf_int {conf_int_vals[j]} rel: {round(rel_conf_int_m, 3)}% +- {round(rel_conf_int_e, 3)}%")

        vari = unbiased_variances[i]
        rel_vari = relative_deviation_percent(vari, data_uv[i])
        print(f"\tvariance: {round(vari, 3)}, rel={round(rel_vari, 3)}%")
        
        skoi = sko_of_xs[i]
        rel_skoi = relative_deviation_percent(skoi, data_sko[i])
        print(f"\tsko: {round(skoi, 3)}, rel={round(rel_skoi, 3)}%")
        
        variation_i = variations[i]
        rel_variation_i = relative_deviation_percent(variation_i, data_var[i])
        print(f"\tvariation: {round(variation_i, 3)}, rel={round(rel_variation_i, 3)}%")
        
    return (expected_values, unbiased_variances, confidence_intervals, sko_of_xs, variations)
        

bounds = [10, 20, 50, 100, 200, 300]
idx300 = bounds.index(300)
conf_int_vals = [0.9, 0.95, 0.99]

data_analysis = (expected_values, unbiased_variances, confidence_intervals, sko_of_xs, variations)
analyze_gen(data_gen, data_analysis, bounds, conf_int_vals)
# Out:
# for bounds 10:
# 	exp_val=15.693, rel=-26.09%
# 	conf_int 0.9: 15.693 +- 17.142
# 	conf_int 0.9 rel: -26.09% +- -15.207%
# 	conf_int 0.95: 15.693 +- 20.45
# 	conf_int 0.95 rel: -26.09% +- -15.207%
# 	conf_int 0.99: 15.693 +- 26.877
# 	conf_int 0.99 rel: -26.09% +- -15.207%
# 	variance: 979.742, rel=-28.101%
# 	sko: 32.994, rel=-15.207%
# 	variation: 2.102, rel=14.725%
# for bounds 20:
# 	exp_val=14.373, rel=-41.913%
# 	conf_int 0.9: 14.373 +- 10.578
# 	conf_int 0.9 rel: -41.913% +- -20.422%
# 	conf_int 0.95: 14.373 +- 12.619
# 	conf_int 0.95 rel: -41.913% +- -20.422%
# 	conf_int 0.99: 14.373 +- 16.585
# 	conf_int 0.99 rel: -41.913% +- -20.422%
# 	variance: 787.616, rel=-36.673%
# 	sko: 28.794, rel=-20.422%
# 	variation: 2.003, rel=36.998%
# for bounds 50:
# 	exp_val=14.786, rel=-42.221%
# 	conf_int 0.9: 14.786 +- 7.08
# 	conf_int 0.9 rel: -42.221% +- -24.351%
# 	conf_int 0.95: 14.786 +- 8.447
# 	conf_int 0.95 rel: -42.221% +- -24.351%
# 	conf_int 0.99: 14.786 +- 11.101
# 	conf_int 0.99 rel: -42.221% +- -24.351%
# 	variance: 910.015, rel=-42.772%
# 	sko: 30.473, rel=-24.351%
# 	variation: 2.061, rel=30.929%
# for bounds 100:
# 	exp_val=20.67, rel=-12.119%
# 	conf_int 0.9: 20.67 +- 5.715
# 	conf_int 0.9 rel: -12.119% +- -12.547%
# 	conf_int 0.95: 20.67 +- 6.818
# 	conf_int 0.95 rel: -12.119% +- -12.547%
# 	conf_int 0.99: 20.67 +- 8.961
# 	conf_int 0.99 rel: -12.119% +- -12.547%
# 	variance: 1197.92, rel=-23.521%
# 	sko: 34.785, rel=-12.547%
# 	variation: 1.683, rel=-0.488%
# for bounds 200:
# 	exp_val=22.859, rel=2.454%
# 	conf_int 0.9: 22.859 +- 4.42
# 	conf_int 0.9 rel: 2.454% +- 0.14%
# 	conf_int 0.95: 22.859 +- 5.272
# 	conf_int 0.95 rel: 2.454% +- 0.14%
# 	conf_int 0.99: 22.859 +- 6.929
# 	conf_int 0.99 rel: 2.454% +- 0.14%
# 	variance: 1440.002, rel=0.281%
# 	sko: 38.043, rel=0.14%
# 	variation: 1.664, rel=-2.258%
# for bounds 300:
# 	exp_val=24.013, rel=5.751%
# 	conf_int 0.9: 24.013 +- 3.678
# 	conf_int 0.9 rel: 5.751% +- -0.495%
# 	conf_int 0.95: 24.013 +- 4.388
# 	conf_int 0.95 rel: 5.751% +- -0.495%
# 	conf_int 0.99: 24.013 +- 5.767
# 	conf_int 0.99 rel: 5.751% +- -0.495%
# 	variance: 1498.531, rel=-0.987%
# 	sko: 38.776, rel=-0.495%
# 	variation: 1.615, rel=-5.907%
# ([15.692829892553496,
#   14.37344352006962,
#   14.786305871804593,
#   20.670340766884255,
#   22.859127273061244,
#   24.01344855559601],
#  [979.7421380554048,
#   787.615919164962,
#   910.014785607609,
#   1197.9200076675415,
#   1440.0016058689448,
#   1498.5312208608398],
#  [[(15.692829892553496, 17.14242279917646),
#    (15.692829892553496, 20.449877471932965),
#    (15.692829892553496, 26.876981820254755)],
#   [(14.37344352006962, 10.578351790266208),
#    (14.37344352006962, 12.61933628053668),
#    (14.37344352006962, 16.58541339727678)],
#   [(14.786305871804593, 7.080497075531181),
#    (14.786305871804593, 8.446606371297086),
#    (14.786305871804593, 11.101254087990458)],
#   [(20.670340766884255, 5.7152321433432975),
#    (20.670340766884255, 6.817927572095473),
#    (20.670340766884255, 8.960704809039767)],
#   [(22.859127273061244, 4.419697171782007),
#    (22.859127273061244, 5.272432414298681),
#    (22.859127273061244, 6.9294826016496955)],
#   [(24.01344855559601, 3.6781959941402813),
#    (24.01344855559601, 4.387866188992667),
#    (24.01344855559601, 5.766909848390362)]],
#  [32.9939748380991,
#   28.79356505531569,
#   30.472717567130957,
#   34.78534475558915,
#   38.042578709166925,
#   38.77554681708632],
#  [2.1024872546254567,
#   2.0032475179042013,
#   2.0608742867438004,
#   1.6828626652986003,
#   1.6642183340918224,
#   1.6147429523632584])

# %%
movs = range(1, 11)
correlation_coefs = []

for mov in movs:
    data_m = data_gen[mov:] + data_gen[0:mov]
    correlation_coefs.append((mov, correlation(data_gen, data_m)))

for mov, corr in correlation_coefs:
    print(f"{mov},\t{round(corr, 3)}")
    
plt_show_correlations([corr for (_, corr) in correlation_coefs])
# Out:
# 1,	0.078
# 2,	-0.02
# 3,	0.01
# 4,	-0.045
# 5,	-0.096
# 6,	0.022
# 7,	0.007
# 8,	-0.034
# 9,	0.004
# 10,	0.046
